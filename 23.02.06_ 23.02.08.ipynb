# %%
import pandas as pd

train = pd.read_csv('titanic_train.csv')
test = pd.read_csv('test.csv')
gs = pd.read_csv('gender_submission.csv')

# %%
tempt = pd.concat([train, test])

# %%
tempt = tempt.merge(gs, on = 'PassengerId', how = 'left')

# %%
tempt['Survived'] = tempt['Survived_x'].fillna(tempt['Survived_y'])
tempt.drop(['Survived_x', 'Survived_y'], axis = 1, inplace = True)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Pclass       1309 non-null   int64
#  2   Name         1309 non-null   object
#  3   Sex          1309 non-null   object
#  4   Age          1046 non-null   float64
#  5   SibSp        1309 non-null   int64
#  6   Parch        1309 non-null   int64
#  7   Ticket       1309 non-null   object
#  8   Fare         1308 non-null   float64
#  9   Cabin        295 non-null    object
#  10  Embarked     1307 non-null   object
#  11  Survived     1309 non-null   float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 132.9+ KB

# %%
tempt.to_csv('titanic_data', index = False)

# %%
titanic_df = pd.read_csv('titanic_data')
titanic_df.head(-2)
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1302         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1303         1304       3                     Henriksson, Miss. Jenny Lovisa
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0       male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1     female  38.0      1      0            PC 17599   71.2833   C85        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3     female  35.0      1      0              113803   53.1000  C123        S
# 4       male  35.0      0      0              373450    8.0500   NaN        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1302  female  37.0      1      0               19928   90.0000   C78        Q
# 1303  female  28.0      0      0              347086    7.7750   NaN        S
# 1304    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  female  39.0      0      0            PC 17758  108.9000  C105        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
#
#       Survived
# 0          0.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          0.0
# ...        ...
# 1302       1.0
# 1303       1.0
# 1304       0.0
# 1305       1.0
# 1306       0.0
#
# [1307 rows x 12 columns]

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1309 non-null   int64
#  1   PassengerId  1309 non-null   int64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  Survived     1309 non-null   float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 133.1+ KB

# %%
titanic_df = pd.read_csv('titanic_data')
titanic_df.head(-2)
# Out:
#       Unnamed: 0  PassengerId  Pclass  \
# 0              0            1       3
# 1              1            2       1
# 2              2            3       3
# 3              3            4       1
# 4              4            5       3
# ...          ...          ...     ...
# 1302        1302         1303       1
# 1303        1303         1304       3
# 1304        1304         1305       3
# 1305        1305         1306       1
# 1306        1306         1307       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 1303                     Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
#
#       Parch              Ticket      Fare Cabin Embarked  Survived
# 0         0           A/5 21171    7.2500   NaN        S       0.0
# 1         0            PC 17599   71.2833   C85        C       1.0
# 2         0    STON/O2. 3101282    7.9250   NaN        S       1.0
# 3         0              113803   53.1000  C123        S       1.0
# 4         0              373450    8.0500   NaN        S       0.0
# ...     ...                 ...       ...   ...      ...       ...
# 1302      0               19928   90.0000   C78        Q       1.0
# 1303      0              347086    7.7750   NaN        S       1.0
# 1304      0           A.5. 3236    8.0500   NaN        S       0.0
# 1305      0            PC 17758  108.9000  C105        C       1.0
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S       0.0
#
# [1307 rows x 13 columns]

# %%
tempt.head(-2)
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1302         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1303         1304       3                     Henriksson, Miss. Jenny Lovisa
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0       male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1     female  38.0      1      0            PC 17599   71.2833   C85        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3     female  35.0      1      0              113803   53.1000  C123        S
# 4       male  35.0      0      0              373450    8.0500   NaN        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1302  female  37.0      1      0               19928   90.0000   C78        Q
# 1303  female  28.0      0      0              347086    7.7750   NaN        S
# 1304    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  female  39.0      0      0            PC 17758  108.9000  C105        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
#
#       Survived
# 0          0.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          0.0
# ...        ...
# 1302       1.0
# 1303       1.0
# 1304       0.0
# 1305       1.0
# 1306       0.0
#
# [1307 rows x 12 columns]

# %%
tempt['g'] = tempt['Survived'].combine_first(tempt['PassengerId'].map(gs.set_index('PassengerId')['Survived']))

# %%
tempt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 417
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  g            1309 non-null   float64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 143.2+ KB

# %%
df1 = pd.DataFrame({'ID' : ['A', 'B', 'C'], 'a' : [4, 5, 6]})
df2 = pd.DataFrame({'ID' : ['B', 'D'], 'b' : [7, 8]})

print(df1)
print(df2)
# Out:
#   ID  a
# 0  A  4
# 1  B  5
# 2  C  6
#   ID  b
# 0  B  7
# 1  D  8

# %%
print(df2.set_index('ID')['b'])
# Out:
# ID
# B    7
# D    8
# Name: b, dtype: int64

# %%
print(df1['ID'].map(df2.set_index('ID')['b']))
# Out:
# 0    NaN
# 1    7.0
# 2    NaN
# Name: ID, dtype: float64

# %%
print(df1['ID'].map(df2['ID']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13080\3301388591.py in <module>
# ----> 1 print(df1['ID'].map(df2['ID']))
#
# NameError: name 'df1' is not defined

# %%
titanic_df = pd.read_csv('titanic_data')
titanic_df.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0       0.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       0.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Pclass       1309 non-null   int64
#  2   Name         1309 non-null   object
#  3   Sex          1309 non-null   object
#  4   Age          1046 non-null   float64
#  5   SibSp        1309 non-null   int64
#  6   Parch        1309 non-null   int64
#  7   Ticket       1309 non-null   object
#  8   Fare         1308 non-null   float64
#  9   Cabin        295 non-null    object
#  10  Embarked     1307 non-null   object
#  11  Survived     1309 non-null   float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
titanic_df['Age'].fillna(titanic_df['Age'].mean(), inplace = True)
titanic_df['Fare'].fillna(titanic_df['Fare'].mean(), inplace = True)
titanic_df['Cabin'].fillna('N', inplace = True)
titanic_df['Embarked'].fillna('N', inplace = True)

# %%
titanic_df.isnull().sum().sum()
# Out:
# 0

# %%
titanic_df['Cabin'] = titanic_df['Cabin'].str[:1]
# Out:
# N    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: Cabin, dtype: int64

# %%
titanic_df.groupby(['Sex', 'Pclass', 'Age'])['Fare'].mean()
# Out:
# Sex     Pclass  Age
# female  1       2.0     151.550000
#                 14.0    120.000000
#                 15.0    211.337500
#                 16.0     61.293067
#                 17.0     82.950000
#                            ...
# male    3       60.5     33.295479
#                 61.0      6.237500
#                 65.0      7.750000
#                 70.5      7.750000
#                 74.0      7.775000
# Name: Fare, Length: 338, dtype: float64

# %%
sns.barplot(data = titanic_df, x = 'Pclass', y = 'Sex', hue = 'Survived')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Sex'>

# %%
group_names = ['Baby', 'Child', 'Adult']

def get_category(age):
    if age <= 1 : return group_names[0]
    if age <= 20 : return group_names[1]
    return group_names[2]

plt.figure(figsize = (10, 6))
titanic_df['Age_cat'] = titanic_df['Age'].apply(lambda x : get_category(x))
sns.barplot(data = titanic_df, x = 'Age_cat', y = 'Survived', hue = 'Sex', order = group_names)
# Out:
# <AxesSubplot:xlabel='Age_cat', ylabel='Survived'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score
# %matplotlib inline

titanic_df = pd.read_csv('titanic_data')

titanic_df['Cabin'] = titanic_df['Cabin'].str[:1]
titanic_df['Age'].fillna(titanic_df['Age'].mean(),inplace=True)
titanic_df['Cabin'].fillna('N',inplace=True)
titanic_df['Embarked'].fillna('N',inplace=True)
titanic_df['Fare'].fillna(0, inplace=True)
titanic_df.drop(['PassengerId','Ticket', 'Name'], axis = 1, inplace = True)

def encode_features(dataDF):
    features = ['Cabin', 'Sex', 'Embarked']
    le = LabelEncoder()
    for feature in features:
        dataDF[feature] = le.fit_transform(dataDF[feature])

    titanic_df = dataDF

encode_features(titanic_df)
target_df = titanic_df['Survived']
feature_df = titanic_df.drop('Survived', axis = 1)
X_train, X_test, y_train, y_test = train_test_split(feature_df, target_df,
                                                    test_size = 0.2, random_state = 11)

dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train, y_train)
result = dt_clf.predict(X_test)
print("accuracy:", accuracy_score(y_test, result))

kfold = KFold(n_splits = 5)
accuracy_list = []
for train_index, test_index in kfold.split(feature_df):
    X_train, X_test = feature_df.values[train_index], feature_df.values[test_index]
    y_train, y_test = target_df.values[train_index], target_df.values[test_index]
    
    dt_clf.fit(X_train, y_train)
    result = dt_clf.predict(X_test)
    accuracy = accuracy_score(y_test, result)
    accuracy_list.append(accuracy)
    
print('accuracy2:', np.mean(accuracy_list))
# Out:
# accuracy: 0.8091603053435115
# accuracy2: 0.802155538007078

# %%
lr_clf = Lo
# Out:
# 4
# (4, 3)
